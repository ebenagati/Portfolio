# %% [markdown]
# ## Beyond the Myths: A Data-Driven Analysis of Common Myths in Football
# An exploratory data analysis project about popular beliefs within the world of football

# %% [markdown]
# ## Problem Statement
# This project explores two common football beliefs: "2-0 is a dangerous scoreline" and "Teams perform better at home"
#
# The goal is to examine the validity of these beliefs using data from the Premier League across the last ten seasons (From 2013/14 to 2023/24)

# %% [markdown]
# ## Initial Setup

# %% [markdown]
# Lets start by importing the libraries which we will use for this project

# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %% [markdown]
# Subsequently, lets import the raw data

# %%
DatasetPath = glob.glob(r'C:\Users\Eben\Documents\Python Project\Football Dataset/*.csv')

# %% [markdown]
# Lets put our raw data into a dataframe in order to undertake some data cleaning & transformation techniques
#
# We use a for loop here to add each file in the Football Dataset folder into a dataframe

# %%
dataframes = []

for file in DatasetPath:
    df = pd.read_csv(file)
    dataframes.append(df)

# %% [markdown]
# Now that we have all of our dataframes let combine it into one dataframe

# %%
df = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# Lets have a quick look at the data

# %%
df
# Out:
#      Div        Date          HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0     E0  16/08/2014           Arsenal  Crystal Palace     2     1   H     1
# 1     E0  16/08/2014         Leicester         Everton     2     2   D     1
# 2     E0  16/08/2014        Man United         Swansea     1     2   A     0
# 3     E0  16/08/2014               QPR            Hull     0     1   A     0
# 4     E0  16/08/2014             Stoke     Aston Villa     0     1   A     0
# ...   ..         ...               ...             ...   ...   ...  ..   ...
# 3795  E0  19/05/2024    Crystal Palace     Aston Villa     5     0   H     2
# 3796  E0  19/05/2024         Liverpool          Wolves     2     0   H     2
# 3797  E0  19/05/2024             Luton          Fulham     2     4   A     1
# 3798  E0  19/05/2024          Man City        West Ham     3     1   H     2
# 3799  E0  19/05/2024  Sheffield United       Tottenham     0     3   A     0
#
#       HTAG HTR  ... AST  HF  AF  HC  AC  HY  AY  HR  AR   Time
# 0        1   D  ...   2  13  19   9   3   2   2   0   1    NaN
# 1        2   A  ...   3  16  10   3   6   1   1   0   0    NaN
# 2        1   A  ...   4  14  20   4   0   2   4   0   0    NaN
# 3        0   D  ...   4  10  10   8   9   1   2   0   0    NaN
# 4        0   D  ...   2  14   9   2   8   0   3   0   0    NaN
# ...    ...  ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..    ...
# 3795     0   H  ...   2  10   8   2   4   1   4   0   0  16:00
# 3796     0   H  ...   3  14  11  10   2   1   1   0   1  16:00
# 3797     2   A  ...   7  15  20   4   4   5   4   0   0  16:00
# 3798     1   H  ...   2   3  12  11   2   0   1   0   0  16:00
# 3799     1   A  ...   9  11   9   2   6   2   0   0   0  16:00
#
# [3800 rows x 24 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# As with any other dataset, some data cleaning techniques will be needed
#
# Below we will loop through the data to see if there is any columns with any missing information

# %%
for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(percent_missing*100)))
# Out:
# Div - 0%
# Date - 0%
# HomeTeam - 0%
# AwayTeam - 0%
# FTHG - 0%
# FTAG - 0%
# FTR - 0%
# HTHG - 0%
# HTAG - 0%
# HTR - 0%
# Referee - 0%
# HS - 0%
# AS - 0%
# HST - 0%
# AST - 0%
# HF - 0%
# AF - 0%
# HC - 0%
# AC - 0%
# HY - 0%
# AY - 0%
# HR - 0%
# AR - 0%
# Time - 50%

# %% [markdown]
# Based on our above code we can see that 50% of the entries in the Time row are missing as we are not going to use this column for any analysis we can just drop the column

# %%
del df["Time"]

# %% [markdown]
# Lets check again to see if Time has been deleted

# %%
for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(percent_missing*100)))
# Out:
# Div - 0%
# Date - 0%
# HomeTeam - 0%
# AwayTeam - 0%
# FTHG - 0%
# FTAG - 0%
# FTR - 0%
# HTHG - 0%
# HTAG - 0%
# HTR - 0%
# Referee - 0%
# HS - 0%
# AS - 0%
# HST - 0%
# AST - 0%
# HF - 0%
# AF - 0%
# HC - 0%
# AC - 0%
# HY - 0%
# AY - 0%
# HR - 0%
# AR - 0%

# %% [markdown]
# Our next step would be to improve our naming conventions of our columns as its pretty ambigious, so lets change these column names to make it easier to understand

# %%
df = df.rename(columns = {
    'FTHG': 'FullTimeHomeTeamGoals',
    'FTAG': 'FullTimeAwayTeamGoals',
    'FTR': 'FullTimeResult',
    'HTHG': 'HalfTimeHomeTeamGoals',
    'HTAG': 'HalfTimeAwayTeamGoals',
    'HTR': 'HalfTimeResult',
    'Referee': 'Referee',
    'HS': 'HomeTeamShots',
    'AS': 'AwayTeamShots',
    'HST': 'HomeTeamShotsOnTarget',
    'AST': 'AwayTeamShotsOnTarget',
    'HF': 'HomeTeamFoulsCommitted',
    'AF': 'AwayTeamFoulsCommitted',
    'HC': 'HomeTeamCorners',
    'AC': 'AwayTeamCorners',
    'HY': 'HomeTeamYellowCards',
    'AY': 'AwayTeamYellowCards',
    'HR': 'HomeTeamRedCards',
    'AR': 'AwayTeamRedCards'})

# %% [markdown]
# Knowing the nature of our dataset, there should not be any duplicate rows, but just to be safe let's remove them anyway

# %%
df.drop_duplicates()
# Out:
#      Div        Date          HomeTeam        AwayTeam  FullTimeHomeTeamGoals  \
# 0     E0  16/08/2014           Arsenal  Crystal Palace                      2
# 1     E0  16/08/2014         Leicester         Everton                      2
# 2     E0  16/08/2014        Man United         Swansea                      1
# 3     E0  16/08/2014               QPR            Hull                      0
# 4     E0  16/08/2014             Stoke     Aston Villa                      0
# ...   ..         ...               ...             ...                    ...
# 3795  E0  19/05/2024    Crystal Palace     Aston Villa                      5
# 3796  E0  19/05/2024         Liverpool          Wolves                      2
# 3797  E0  19/05/2024             Luton          Fulham                      2
# 3798  E0  19/05/2024          Man City        West Ham                      3
# 3799  E0  19/05/2024  Sheffield United       Tottenham                      0
#
#       FullTimeAwayTeamGoals FullTimeResult  HalfTimeHomeTeamGoals  \
# 0                         1              H                      1
# 1                         2              D                      1
# 2                         2              A                      0
# 3                         1              A                      0
# 4                         1              A                      0
# ...                     ...            ...                    ...
# 3795                      0              H                      2
# 3796                      0              H                      2
# 3797                      4              A                      1
# 3798                      1              H                      2
# 3799                      3              A                      0
#
#       HalfTimeAwayTeamGoals HalfTimeResult  ... HomeTeamShotsOnTarget  \
# 0                         1              D  ...                     6
# 1                         2              A  ...                     3
# 2                         1              A  ...                     5
# 3                         0              D  ...                     6
# 4                         0              D  ...                     2
# ...                     ...            ...  ...                   ...
# 3795                      0              H  ...                     9
# 3796                      0              H  ...                    14
# 3797                      2              A  ...                     6
# 3798                      1              H  ...                    12
# 3799                      1              A  ...                     1
#
#       AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  AwayTeamFoulsCommitted  \
# 0                         2                      13                      19
# 1                         3                      16                      10
# 2                         4                      14                      20
# 3                         4                      10                      10
# 4                         2                      14                       9
# ...                     ...                     ...                     ...
# 3795                      2                      10                       8
# 3796                      3                      14                      11
# 3797                      7                      15                      20
# 3798                      2                       3                      12
# 3799                      9                      11                       9
#
#       HomeTeamCorners  AwayTeamCorners  HomeTeamYellowCards  \
# 0                   9                3                    2
# 1                   3                6                    1
# 2                   4                0                    2
# 3                   8                9                    1
# 4                   2                8                    0
# ...               ...              ...                  ...
# 3795                2                4                    1
# 3796               10                2                    1
# 3797                4                4                    5
# 3798               11                2                    0
# 3799                2                6                    2
#
#       AwayTeamYellowCards  HomeTeamRedCards  AwayTeamRedCards
# 0                       2                 0                 1
# 1                       1                 0                 0
# 2                       4                 0                 0
# 3                       2                 0                 0
# 4                       3                 0                 0
# ...                   ...               ...               ...
# 3795                    4                 0                 0
# 3796                    1                 0                 1
# 3797                    4                 0                 0
# 3798                    1                 0                 0
# 3799                    0                 0                 0
#
# [3800 rows x 23 columns]

# %% [markdown]
# Let's have a look to see if there are any abbreviations within our team names

# %%
df["HomeTeam"].unique()
# Out:
# array(['Arsenal', 'Leicester', 'Man United', 'QPR', 'Stoke', 'West Brom',
#        'West Ham', 'Liverpool', 'Newcastle', 'Burnley', 'Aston Villa',
#        'Chelsea', 'Crystal Palace', 'Everton', 'Southampton', 'Swansea',
#        'Hull', 'Sunderland', 'Tottenham', 'Man City', 'Bournemouth',
#        'Norwich', 'Watford', 'Middlesbrough', 'Brighton', 'Huddersfield',
#        'Fulham', 'Wolves', 'Cardiff', 'Sheffield United', 'Leeds',
#        'Brentford', "Nott'm Forest", 'Luton'], dtype=object)

# %% [markdown]
# We can see the Nott'm Forrest is an abbreviation so lets change it to its original name just to further improve the clarity within our data

# %%
df['HomeTeam'] = df['HomeTeam'].replace({"Nott'm Forest": "Nottingham Forest"})
df['AwayTeam'] = df['AwayTeam'].replace({"Nott'm Forest": "Nottingham Forest"})

# %% [markdown]
# Peforming a sense check of the data types will help me to see if any additional transformation is required

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3800 entries, 0 to 3799
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Div                     3800 non-null   object
#  1   Date                    3800 non-null   object
#  2   HomeTeam                3800 non-null   object
#  3   AwayTeam                3800 non-null   object
#  4   FullTimeHomeTeamGoals   3800 non-null   int64
#  5   FullTimeAwayTeamGoals   3800 non-null   int64
#  6   FullTimeResult          3800 non-null   object
#  7   HalfTimeHomeTeamGoals   3800 non-null   int64
#  8   HalfTimeAwayTeamGoals   3800 non-null   int64
#  9   HalfTimeResult          3800 non-null   object
#  10  Referee                 3800 non-null   object
#  11  HomeTeamShots           3800 non-null   int64
#  12  AwayTeamShots           3800 non-null   int64
#  13  HomeTeamShotsOnTarget   3800 non-null   int64
#  14  AwayTeamShotsOnTarget   3800 non-null   int64
#  15  HomeTeamFoulsCommitted  3800 non-null   int64
#  16  AwayTeamFoulsCommitted  3800 non-null   int64
#  17  HomeTeamCorners         3800 non-null   int64
#  18  AwayTeamCorners         3800 non-null   int64
#  19  HomeTeamYellowCards     3800 non-null   int64
#  20  AwayTeamYellowCards     3800 non-null   int64
#  21  HomeTeamRedCards        3800 non-null   int64
#  22  AwayTeamRedCards        3800 non-null   int64
# dtypes: int64(16), object(7)
# memory usage: 682.9+ KB

# %% [markdown]
# ## Analysis
# Let's start by filtering out the rows in which the Home team have been winning 2-0 at half  time & also rows in which the Away team have been winning 2-0 at half time
#
# Afterwards we will then see how often this has happened

# %%
HomeWinning2 = df[(df["HalfTimeHomeTeamGoals"] == 2) & (df["HalfTimeAwayTeamGoals"] == 0)]
HomeWinning2
# Out:
#      Div        Date        HomeTeam     AwayTeam  FullTimeHomeTeamGoals  \
# 13    E0  23/08/2014         Everton      Arsenal                      2
# 25    E0  30/08/2014         Swansea    West Brom                      3
# 27    E0  31/08/2014     Aston Villa         Hull                      2
# 34    E0  13/09/2014     Southampton    Newcastle                      4
# 58    E0  28/09/2014       West Brom      Burnley                      4
# ...   ..         ...             ...          ...                    ...
# 3762  E0  27/04/2024     Aston Villa      Chelsea                      2
# 3775  E0  05/05/2024       Liverpool    Tottenham                      4
# 3776  E0  06/05/2024  Crystal Palace   Man United                      4
# 3795  E0  19/05/2024  Crystal Palace  Aston Villa                      5
# 3796  E0  19/05/2024       Liverpool       Wolves                      2
#
#       FullTimeAwayTeamGoals FullTimeResult  HalfTimeHomeTeamGoals  \
# 13                        2              D                      2
# 25                        0              H                      2
# 27                        1              H                      2
# 34                        0              H                      2
# 58                        0              H                      2
# ...                     ...            ...                    ...
# 3762                      2              D                      2
# 3775                      2              H                      2
# 3776                      0              H                      2
# 3795                      0              H                      2
# 3796                      0              H                      2
#
#       HalfTimeAwayTeamGoals HalfTimeResult  ... HomeTeamShotsOnTarget  \
# 13                        0              H  ...                     2
# 25                        0              H  ...                     8
# 27                        0              H  ...                     4
# 34                        0              H  ...                     7
# 58                        0              H  ...                     6
# ...                     ...            ...  ...                   ...
# 3762                      0              H  ...                     4
# 3775                      0              H  ...                    13
# 3776                      0              H  ...                    10
# 3795                      0              H  ...                     9
# 3796                      0              H  ...                    14
#
#       AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  AwayTeamFoulsCommitted  \
# 13                        3                      10                      18
# 25                        2                      10                       8
# 27                        3                       9                      10
# 34                        4                      15                       7
# 58                        2                       7                       9
# ...                     ...                     ...                     ...
# 3762                      5                      13                      14
# 3775                      6                      14                      12
# 3776                      2                      12                       8
# 3795                      2                      10                       8
# 3796                      3                      14                      11
#
#       HomeTeamCorners  AwayTeamCorners  HomeTeamYellowCards  \
# 13                  3                3                    1
# 25                  0                7                    1
# 27                  3                7                    1
# 34                  5                5                    0
# 58                 10                2                    1
# ...               ...              ...                  ...
# 3762                2                4                    3
# 3775                8                3                    1
# 3776                6                3                    1
# 3795                2                4                    1
# 3796               10                2                    1
#
#       AwayTeamYellowCards  HomeTeamRedCards  AwayTeamRedCards
# 13                      4                 0                 0
# 25                      2                 0                 0
# 27                      4                 0                 0
# 34                      2                 0                 0
# 58                      2                 0                 0
# ...                   ...               ...               ...
# 3762                    5                 0                 0
# 3775                    4                 0                 0
# 3776                    1                 0                 0
# 3795                    4                 0                 0
# 3796                    1                 0                 1
#
# [288 rows x 23 columns]

# %%
AwayWinning2=df[(df["HalfTimeAwayTeamGoals"] == 2) & (df["HalfTimeHomeTeamGoals"] == 0)]
AwayWinning2
# Out:
#      Div        Date          HomeTeam           AwayTeam  \
# 12    E0  23/08/2014    Crystal Palace           West Ham
# 84    E0  25/10/2014         West Brom     Crystal Palace
# 108   E0  09/11/2014         Tottenham              Stoke
# 188   E0  28/12/2014          West Ham            Arsenal
# 227   E0  31/01/2015         West Brom          Tottenham
# ...   ..         ...               ...                ...
# 3695  E0  10/03/2024          West Ham            Burnley
# 3743  E0  20/04/2024             Luton          Brentford
# 3744  E0  20/04/2024  Sheffield United            Burnley
# 3783  E0  11/05/2024            Wolves     Crystal Palace
# 3793  E0  19/05/2024           Burnley  Nottingham Forest
#
#       FullTimeHomeTeamGoals  FullTimeAwayTeamGoals FullTimeResult  \
# 12                        1                      3              A
# 84                        2                      2              D
# 108                       1                      2              A
# 188                       1                      2              A
# 227                       0                      3              A
# ...                     ...                    ...            ...
# 3695                      2                      2              D
# 3743                      1                      5              A
# 3744                      1                      4              A
# 3783                      1                      3              A
# 3793                      1                      2              A
#
#       HalfTimeHomeTeamGoals  HalfTimeAwayTeamGoals HalfTimeResult  ...  \
# 12                        0                      2              A  ...
# 84                        0                      2              A  ...
# 108                       0                      2              A  ...
# 188                       0                      2              A  ...
# 227                       0                      2              A  ...
# ...                     ...                    ...            ...  ...
# 3695                      0                      2              A  ...
# 3743                      0                      2              A  ...
# 3744                      0                      2              A  ...
# 3783                      0                      2              A  ...
# 3793                      0                      2              A  ...
#
#      HomeTeamShotsOnTarget  AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  \
# 12                       4                      8                      14
# 84                       4                      6                      14
# 108                      4                      4                      20
# 188                      4                      7                      12
# 227                      4                      4                       8
# ...                    ...                    ...                     ...
# 3695                     4                      4                      11
# 3743                     3                      9                      13
# 3744                    11                      9                      10
# 3783                     7                      3                      13
# 3793                     3                      6                      11
#
#       AwayTeamFoulsCommitted  HomeTeamCorners  AwayTeamCorners  \
# 12                        11                6                9
# 84                         8                6                3
# 108                       13                5                5
# 188                       13                7                8
# 227                       13                6                3
# ...                      ...              ...              ...
# 3695                      18                4                4
# 3743                       9                4                9
# 3744                       9               11                2
# 3783                      12                8                3
# 3793                       5                4                3
#
#       HomeTeamYellowCards  AwayTeamYellowCards  HomeTeamRedCards  \
# 12                      1                    3                 0
# 84                      3                    1                 0
# 108                     3                    2                 1
# 188                     3                    3                 0
# 227                     2                    1                 0
# ...                   ...                  ...               ...
# 3695                    2                    4                 0
# 3743                    1                    2                 0
# 3744                    1                    0                 0
# 3783                    3                    2                 0
# 3793                    1                    0                 0
#
#       AwayTeamRedCards
# 12                   0
# 84                   0
# 108                  0
# 188                  0
# 227                  0
# ...                ...
# 3695                 0
# 3743                 0
# 3744                 0
# 3783                 1
# 3793                 0
#
# [194 rows x 23 columns]

# %% [markdown]
# Amount of times the Home team has been winning 2-0

# %%
HomeWinning2.shape[0]
# Out:
# 288

# %% [markdown]
# Amount of times the Away team has been winning 2-0

# %%
AwayWinning2.shape[0]
# Out:
# 194

# %% [markdown]
# Let's take a look at the full time results when the home team was winning 2-0, subsequently we will plot this on a pie chart

# %%
HomeWinning2 = HomeWinning2.copy()

HomeWinning2.loc[:, "FullTimeOutcome"] = HomeWinning2.apply(
    lambda row: "Win" if row["FullTimeHomeTeamGoals"] > row["FullTimeAwayTeamGoals"] 
                else "Draw" if row["FullTimeHomeTeamGoals"] == row["FullTimeAwayTeamGoals"] 
                else "Loss", axis=1
)

OutcomeHome2 = HomeWinning2["FullTimeOutcome"].value_counts()
OutcomeHome2.plot(
    kind='pie', 
    autopct='%1.2f%%',
    figsize=(8, 8), 
    colors=['#66b3ff', '#99ff99', '#ff9999'])
plt.ylabel('Outcome');
plt.title("Full-Time Outcome When Home Team Leads 2-0 at Half-Time");

# %% [markdown]
# Now lets repeat the above for when the Away team is leading 2-0 at half time

# %%
AwayWinning2 = AwayWinning2.copy()
AwayWinning2["FullTimeOutcome"] = AwayWinning2.apply(
    lambda row: "Win" if row["FullTimeAwayTeamGoals"] > row["FullTimeHomeTeamGoals"] 
                else "Draw" if row["FullTimeAwayTeamGoals"] == row["FullTimeHomeTeamGoals"] 
                else "Loss", axis=1
)

OutcomeAway2 = AwayWinning2["FullTimeOutcome"].value_counts()
OutcomeAway2.plot(
    kind='pie', 
    autopct='%1.2f%%',
    figsize=(8, 8), 
    colors=['#66b3ff', '#99ff99', '#ff9999']) 
plt.ylabel('Outcome');
plt.title("Full-Time Outcome When Away Team Leads 2-0 at Half-Time");

# %% [markdown]
# We can see that when a team is winning 2-0 at halftime they are overwhelmingly likely to win the game - 93.4% and 89.18% respectively for Home and Away teams.<br />
# This indicates that 2-0 is not a dangerous scoreline as leading teams are very likely to finish the game with a win based on the historical data we have collected.<br />
# A possible explanation is that when a team is winning at half time, they are just simply more likely to win the game because the losing team has a bigger deficit to overturn, our below analysis will explore this further.<br /><br />
# An interesting insight that can be derived from comparing the two pie charts is that there is a home advtange. When the Away team is leading by 2-0 at half time they are less likely to win the game compared to the Home team (89.18% vs 93.4%) - we will explore this insight further later on within this project.

# %% [markdown]
# Let's take a look at games were the Home team is winning 1-0 at half time

# %%
HomeWinning1 = df[(df["HalfTimeHomeTeamGoals"] == 1) & (df["HalfTimeAwayTeamGoals"] == 0)]
HomeWinning1
# Out:
#      Div        Date    HomeTeam          AwayTeam  FullTimeHomeTeamGoals  \
# 7     E0  17/08/2014   Liverpool       Southampton                      2
# 15    E0  23/08/2014     Swansea           Burnley                      1
# 16    E0  24/08/2014        Hull             Stoke                      1
# 19    E0  25/08/2014    Man City         Liverpool                      3
# 24    E0  30/08/2014         QPR        Sunderland                      1
# ...   ..         ...         ...               ...                    ...
# 3766  E0  02/05/2024     Chelsea         Tottenham                      2
# 3768  E0  04/05/2024     Arsenal       Bournemouth                      3
# 3779  E0  11/05/2024     Everton  Sheffield United                      1
# 3789  E0  15/05/2024  Man United         Newcastle                      3
# 3794  E0  19/05/2024     Chelsea       Bournemouth                      2
#
#       FullTimeAwayTeamGoals FullTimeResult  HalfTimeHomeTeamGoals  \
# 7                         1              H                      1
# 15                        0              H                      1
# 16                        1              D                      1
# 19                        1              H                      1
# 24                        0              H                      1
# ...                     ...            ...                    ...
# 3766                      0              H                      1
# 3768                      0              H                      1
# 3779                      0              H                      1
# 3789                      2              H                      1
# 3794                      1              H                      1
#
#       HalfTimeAwayTeamGoals HalfTimeResult  ... HomeTeamShotsOnTarget  \
# 7                         0              H  ...                     5
# 15                        0              H  ...                     5
# 16                        0              H  ...                     2
# 19                        0              H  ...                     4
# 24                        0              H  ...                     5
# ...                     ...            ...  ...                   ...
# 3766                      0              H  ...                     5
# 3768                      0              H  ...                     9
# 3779                      0              H  ...                     6
# 3789                      0              H  ...                     8
# 3794                      0              H  ...                     6
#
#       AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  AwayTeamFoulsCommitted  \
# 7                         6                       8                      11
# 15                        1                      14                      13
# 16                        3                      10                      10
# 19                        3                      13                       7
# 24                        6                       8                       9
# ...                     ...                     ...                     ...
# 3766                      3                      12                      16
# 3768                      2                      16                      12
# 3779                      1                       6                      11
# 3789                      8                      16                       7
# 3794                      5                       5                       9
#
#       HomeTeamCorners  AwayTeamCorners  HomeTeamYellowCards  \
# 7                   2                6                    1
# 15                  2                3                    2
# 16                  4                5                    1
# 19                  6                7                    1
# 24                  4                6                    1
# ...               ...              ...                  ...
# 3766                4                9                    0
# 3768                6                1                    2
# 3779                3                6                    1
# 3789                9                9                    3
# 3794                6                5                    2
#
#       AwayTeamYellowCards  HomeTeamRedCards  AwayTeamRedCards
# 7                       2                 0                 0
# 15                      1                 0                 0
# 16                      3                 1                 0
# 19                      1                 0                 0
# 24                      2                 0                 0
# ...                   ...               ...               ...
# 3766                    1                 0                 0
# 3768                    3                 0                 0
# 3779                    2                 0                 0
# 3789                    3                 0                 0
# 3794                    3                 0                 0
#
# [741 rows x 23 columns]

# %% [markdown]
# Let's repeat the above but for Away teams now

# %%
AwayWinning1 = df[(df["HalfTimeHomeTeamGoals"] == 0) & (df["HalfTimeAwayTeamGoals"] == 1)]
AwayWinning1
# Out:
#      Div        Date          HomeTeam     AwayTeam  FullTimeHomeTeamGoals  \
# 2     E0  16/08/2014        Man United      Swansea                      1
# 8     E0  17/08/2014         Newcastle     Man City                      0
# 29    E0  31/08/2014         Tottenham    Liverpool                      0
# 30    E0  13/09/2014           Arsenal     Man City                      2
# 33    E0  13/09/2014         Liverpool  Aston Villa                      0
# ...   ..         ...               ...          ...                    ...
# 3777  E0  11/05/2024            Fulham     Man City                      0
# 3782  E0  11/05/2024          West Ham        Luton                      3
# 3785  E0  12/05/2024        Man United      Arsenal                      0
# 3788  E0  15/05/2024          Brighton      Chelsea                      1
# 3799  E0  19/05/2024  Sheffield United    Tottenham                      0
#
#       FullTimeAwayTeamGoals FullTimeResult  HalfTimeHomeTeamGoals  \
# 2                         2              A                      0
# 8                         2              A                      0
# 29                        3              A                      0
# 30                        2              D                      0
# 33                        1              A                      0
# ...                     ...            ...                    ...
# 3777                      4              A                      0
# 3782                      1              H                      0
# 3785                      1              A                      0
# 3788                      2              A                      0
# 3799                      3              A                      0
#
#       HalfTimeAwayTeamGoals HalfTimeResult  ... HomeTeamShotsOnTarget  \
# 2                         1              A  ...                     5
# 8                         1              A  ...                     0
# 29                        1              A  ...                     1
# 30                        1              A  ...                     6
# 33                        1              A  ...                     1
# ...                     ...            ...  ...                   ...
# 3777                      1              A  ...                     1
# 3782                      1              A  ...                     8
# 3785                      1              A  ...                     2
# 3788                      1              A  ...                     2
# 3799                      1              A  ...                     1
#
#       AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  AwayTeamFoulsCommitted  \
# 2                         4                      14                      20
# 8                         5                       8                      11
# 29                        8                      14                      11
# 30                        8                      11                      15
# 33                        1                       9                      10
# ...                     ...                     ...                     ...
# 3777                      9                       9                       6
# 3782                      1                       9                      15
# 3785                      5                       5                       6
# 3788                      6                      13                      14
# 3799                      9                      11                       9
#
#       HomeTeamCorners  AwayTeamCorners  HomeTeamYellowCards  \
# 2                   4                0                    2
# 8                   3                3                    1
# 29                  7                3                    0
# 30                  0                3                    3
# 33                  7                6                    2
# ...               ...              ...                  ...
# 3777                1                7                    1
# 3782                7                6                    1
# 3785                4                7                    0
# 3788                4                6                    2
# 3799                2                6                    2
#
#       AwayTeamYellowCards  HomeTeamRedCards  AwayTeamRedCards
# 2                       4                 0                 0
# 8                       5                 0                 0
# 29                      4                 0                 0
# 30                      4                 0                 0
# 33                      1                 0                 0
# ...                   ...               ...               ...
# 3777                    0                 1                 0
# 3782                    3                 0                 0
# 3785                    2                 0                 0
# 3788                    2                 0                 1
# 3799                    0                 0                 0
#
# [573 rows x 23 columns]

# %% [markdown]
# Number of times a Home team has been winning 1-0 at half time:

# %%
HomeWinning1.shape[0]
# Out:
# 741

# %% [markdown]
# Number of times a Away team has been winning 1-0 at half time:

# %%
# Number of times a away team has been winning 1-0
AwayWinning1.shape[0]
# Out:
# 573

# %% [markdown]
# We are now going to perform the same analysis that we did for when teams were winning 2-0 at half time

# %%
HomeWinning1 = HomeWinning1.copy()
HomeWinning1["FullTimeOutcome"] = HomeWinning1.apply(
    lambda row: "Win" if row["FullTimeHomeTeamGoals"] > row["FullTimeAwayTeamGoals"] 
                else "Draw" if row["FullTimeHomeTeamGoals"] == row["FullTimeAwayTeamGoals"] 
                else "Loss", axis=1
)

OutcomeHome1 = HomeWinning1["FullTimeOutcome"].value_counts()
OutcomeHome1.plot(
    kind='pie', 
    autopct='%1.2f%%',
    figsize=(8, 8), 
    colors=['#66b3ff', '#99ff99', '#ff9999']) 
plt.ylabel('Outcome');
plt.title("Full-Time Outcome When Home Team Leads 1-0 at Half-Time");

# %%
AwayWinning1 = AwayWinning1.copy()
AwayWinning1["FullTimeOutcome"] = AwayWinning1.apply(
    lambda row: "Win" if row["FullTimeAwayTeamGoals"] > row["FullTimeHomeTeamGoals"] 
                else "Draw" if row["FullTimeAwayTeamGoals"] == row["FullTimeHomeTeamGoals"] 
                else "Loss", axis=1
)

OutcomeAway1 = AwayWinning1["FullTimeOutcome"].value_counts()
OutcomeAway1.plot(
    kind='pie', 
    autopct='%1.1f%%',
    figsize=(8, 8), 
    colors=['#66b3ff', '#99ff99', '#ff9999']) 
plt.ylabel('Outcome');
plt.title("Full-Time Outcome When Away Team Leads 1-0 at Half-Time");

# %% [markdown]
# Let's repeat the above but for situations where the team is leading by 3-0 at half time

# %%
HomeWinning3 = df[(df["HalfTimeHomeTeamGoals"] == 3) & (df["HalfTimeAwayTeamGoals"] == 0)]
HomeWinning3
# Out:
#      Div        Date           HomeTeam        AwayTeam  \
# 18    E0  24/08/2014          Tottenham             QPR
# 38    E0  14/09/2014         Man United             QPR
# 76    E0  18/10/2014        Southampton      Sunderland
# 145   E0  06/12/2014              Stoke         Arsenal
# 224   E0  31/01/2015         Man United       Leicester
# ...   ..         ...                ...             ...
# 3630  E0  30/01/2024              Luton        Brighton
# 3639  E0  03/02/2024           Brighton  Crystal Palace
# 3714  E0  02/04/2024  Nottingham Forest          Fulham
# 3772  E0  04/05/2024           Man City          Wolves
# 3774  E0  05/05/2024            Chelsea        West Ham
#
#       FullTimeHomeTeamGoals  FullTimeAwayTeamGoals FullTimeResult  \
# 18                        4                      0              H
# 38                        4                      0              H
# 76                        8                      0              H
# 145                       3                      2              H
# 224                       3                      1              H
# ...                     ...                    ...            ...
# 3630                      4                      0              H
# 3639                      4                      1              H
# 3714                      3                      1              H
# 3772                      5                      1              H
# 3774                      5                      0              H
#
#       HalfTimeHomeTeamGoals  HalfTimeAwayTeamGoals HalfTimeResult  ...  \
# 18                        3                      0              H  ...
# 38                        3                      0              H  ...
# 76                        3                      0              H  ...
# 145                       3                      0              H  ...
# 224                       3                      0              H  ...
# ...                     ...                    ...            ...  ...
# 3630                      3                      0              H  ...
# 3639                      3                      0              H  ...
# 3714                      3                      0              H  ...
# 3772                      3                      0              H  ...
# 3774                      3                      0              H  ...
#
#      HomeTeamShotsOnTarget  AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  \
# 18                       5                      1                      12
# 38                       9                      2                      11
# 76                      11                      1                      11
# 145                      4                      6                      17
# 224                      5                      1                       8
# ...                    ...                    ...                     ...
# 3630                     8                      2                      13
# 3639                     6                      5                       8
# 3714                     4                      3                       7
# 3772                    12                      1                       4
# 3774                    14                      2                      12
#
#       AwayTeamFoulsCommitted  HomeTeamCorners  AwayTeamCorners  \
# 18                         6                7                6
# 38                         8                3                1
# 76                         8                5                6
# 145                       14                3                9
# 224                       12                4                3
# ...                      ...              ...              ...
# 3630                      14                7                4
# 3639                      14                3                2
# 3714                       8                3                8
# 3772                      17                6                0
# 3774                      10                8                6
#
#       HomeTeamYellowCards  AwayTeamYellowCards  HomeTeamRedCards  \
# 18                      0                    1                 0
# 38                      1                    0                 0
# 76                      1                    3                 0
# 145                     3                    2                 0
# 224                     0                    1                 0
# ...                   ...                  ...               ...
# 3630                    2                    2                 0
# 3639                    1                    3                 0
# 3714                    0                    0                 0
# 3772                    0                    4                 0
# 3774                    1                    3                 0
#
#       AwayTeamRedCards
# 18                   0
# 38                   0
# 76                   0
# 145                  1
# 224                  0
# ...                ...
# 3630                 0
# 3639                 0
# 3714                 0
# 3772                 0
# 3774                 0
#
# [75 rows x 23 columns]

# %%
AwayWinning3 = df[(df["HalfTimeHomeTeamGoals"] == 0) & (df["HalfTimeAwayTeamGoals"] == 3)]
AwayWinning3
# Out:
#      Div        Date          HomeTeam     AwayTeam  FullTimeHomeTeamGoals  \
# 40    E0  20/09/2014       Aston Villa      Arsenal                      0
# 179   E0  26/12/2014         West Brom     Man City                      1
# 305   E0  04/04/2015         West Brom          QPR                      1
# 348   E0  04/05/2015              Hull      Arsenal                      1
# 625   E0  06/02/2016             Stoke      Everton                      0
# 685   E0  02/04/2016       Bournemouth     Man City                      0
# 787   E0  27/08/2016           Watford      Arsenal                      1
# 869   E0  06/11/2016           Swansea   Man United                      1
# 949   E0  01/01/2017           Watford    Tottenham                      1
# 989   E0  01/02/2017          West Ham     Man City                      0
# 1133  E0  21/05/2017              Hull    Tottenham                      1
# 1142  E0  12/08/2017           Chelsea      Burnley                      2
# 1186  E0  16/09/2017           Watford     Man City                      0
# 1202  E0  30/09/2017      Huddersfield    Tottenham                      0
# 1257  E0  18/11/2017         West Brom      Chelsea                      0
# 1272  E0  28/11/2017           Watford   Man United                      2
# 1306  E0  13/12/2017       Southampton    Leicester                      1
# 1317  E0  17/12/2017       Bournemouth    Liverpool                      0
# 1419  E0  01/03/2018           Arsenal     Man City                      0
# 1446  E0  31/03/2018           Everton     Man City                      1
# 1572  E0  22/09/2018           Cardiff     Man City                      0
# 1596  E0  06/10/2018           Watford  Bournemouth                      0
# 1646  E0  24/11/2018          West Ham     Man City                      0
# 1721  E0  01/01/2019           Cardiff    Tottenham                      0
# 1945  E0  14/09/2019            Wolves      Chelsea                      2
# 2068  E0  15/12/2019           Arsenal     Man City                      0
# 2342  E0  01/11/2020       Aston Villa  Southampton                      3
# 2407  E0  19/12/2020    Crystal Palace    Liverpool                      0
# 2442  E0  03/01/2021           Chelsea     Man City                      1
# 2583  E0  10/04/2021    Crystal Palace      Chelsea                      1
# 2604  E0  25/04/2021            Wolves      Burnley                      0
# 2746  E0  23/10/2021          Brighton     Man City                      1
# 2825  E0  18/12/2021             Leeds      Arsenal                      1
# 2845  E0  01/01/2022    Crystal Palace     West Ham                      2
# 2909  E0  26/02/2022             Leeds    Tottenham                      0
# 3010  E0  08/05/2022           Norwich     West Ham                      0
# 3110  E0  01/10/2022            Fulham    Newcastle                      1
# 3189  E0  26/12/2022         Leicester    Newcastle                      0
# 3276  E0  25/02/2023       Bournemouth     Man City                      1
# 3297  E0  12/03/2023            Fulham      Arsenal                      0
# 3352  E0  23/04/2023       Bournemouth     West Ham                      0
# 3385  E0  08/05/2023          Brighton      Everton                      1
# 3478  E0  24/09/2023  Sheffield United    Newcastle                      0
# 3698  E0  13/03/2024       Bournemouth        Luton                      4
# 3755  E0  25/04/2024          Brighton     Man City                      0
# 3764  E0  28/04/2024         Tottenham      Arsenal                      2
# 3770  E0  04/05/2024           Burnley    Newcastle                      1
# 3791  E0  19/05/2024         Brentford    Newcastle                      2
#
#       FullTimeAwayTeamGoals FullTimeResult  HalfTimeHomeTeamGoals  \
# 40                        3              A                      0
# 179                       3              A                      0
# 305                       4              A                      0
# 348                       3              A                      0
# 625                       3              A                      0
# 685                       4              A                      0
# 787                       3              A                      0
# 869                       3              A                      0
# 949                       4              A                      0
# 989                       4              A                      0
# 1133                      7              A                      0
# 1142                      3              A                      0
# 1186                      6              A                      0
# 1202                      4              A                      0
# 1257                      4              A                      0
# 1272                      4              A                      0
# 1306                      4              A                      0
# 1317                      4              A                      0
# 1419                      3              A                      0
# 1446                      3              A                      0
# 1572                      5              A                      0
# 1596                      4              A                      0
# 1646                      4              A                      0
# 1721                      3              A                      0
# 1945                      5              A                      0
# 2068                      3              A                      0
# 2342                      4              A                      0
# 2407                      7              A                      0
# 2442                      3              A                      0
# 2583                      4              A                      0
# 2604                      4              A                      0
# 2746                      4              A                      0
# 2825                      4              A                      0
# 2845                      3              A                      0
# 2909                      4              A                      0
# 3010                      4              A                      0
# 3110                      4              A                      0
# 3189                      3              A                      0
# 3276                      4              A                      0
# 3297                      3              A                      0
# 3352                      4              A                      0
# 3385                      5              A                      0
# 3478                      8              A                      0
# 3698                      3              H                      0
# 3755                      4              A                      0
# 3764                      3              A                      0
# 3770                      4              A                      0
# 3791                      4              A                      0
#
#       HalfTimeAwayTeamGoals HalfTimeResult  ... HomeTeamShotsOnTarget  \
# 40                        3              A  ...                     2
# 179                       3              A  ...                     6
# 305                       3              A  ...                     6
# 348                       3              A  ...                     1
# 625                       3              A  ...                     3
# 685                       3              A  ...                     2
# 787                       3              A  ...                     6
# 869                       3              A  ...                     1
# 949                       3              A  ...                     2
# 989                       3              A  ...                     1
# 1133                      3              A  ...                     4
# 1142                      3              A  ...                     6
# 1186                      3              A  ...                     1
# 1202                      3              A  ...                     1
# 1257                      3              A  ...                     2
# 1272                      3              A  ...                     3
# 1306                      3              A  ...                     4
# 1317                      3              A  ...                     2
# 1419                      3              A  ...                     5
# 1446                      3              A  ...                     2
# 1572                      3              A  ...                     2
# 1596                      3              A  ...                     2
# 1646                      3              A  ...                     1
# 1721                      3              A  ...                     3
# 1945                      3              A  ...                     4
# 2068                      3              A  ...                     1
# 2342                      3              A  ...                    10
# 2407                      3              A  ...                     3
# 2442                      3              A  ...                     2
# 2583                      3              A  ...                     1
# 2604                      3              A  ...                     2
# 2746                      3              A  ...                     5
# 2825                      3              A  ...                     2
# 2845                      3              A  ...                     6
# 2909                      3              A  ...                     3
# 3010                      3              A  ...                     2
# 3110                      3              A  ...                     1
# 3189                      3              A  ...                     2
# 3276                      3              A  ...                     2
# 3297                      3              A  ...                     2
# 3352                      3              A  ...                     5
# 3385                      3              A  ...                     5
# 3478                      3              A  ...                     1
# 3698                      3              A  ...                    10
# 3755                      3              A  ...                     3
# 3764                      3              A  ...                     2
# 3770                      3              A  ...                     5
# 3791                      3              A  ...                     5
#
#       AwayTeamShotsOnTarget  HomeTeamFoulsCommitted  AwayTeamFoulsCommitted  \
# 40                        3                      11                       9
# 179                       5                       5                       9
# 305                       7                       6                      15
# 348                       9                       8                      11
# 625                       6                      11                       8
# 685                       7                       9                       8
# 787                       7                      18                      15
# 869                       3                       9                      16
# 949                       6                      11                       6
# 989                       4                      11                      14
# 1133                     14                      14                       5
# 1142                      5                      16                      11
# 1186                     10                       8                       6
# 1202                      7                       7                       4
# 1257                      7                      13                      12
# 1272                      7                      12                      10
# 1306                     11                      13                       9
# 1317                      7                       5                      10
# 1419                      5                      11                      11
# 1446                      4                      10                       8
# 1572                     10                       6                       4
# 1596                      7                      11                       9
# 1646                      6                       6                       3
# 1721                      4                       6                       6
# 1945                      6                       8                      11
# 2068                      7                       9                      24
# 2342                      4                      12                      17
# 2407                      8                       5                      11
# 2442                      6                      11                      10
# 2583                     10                       7                      12
# 2604                      7                       8                       9
# 2746                     14                      10                       6
# 2825                     12                      11                       7
# 2845                      5                       6                      16
# 2909                     11                      16                      11
# 3010                      5                       7                       7
# 3110                     10                       9                      10
# 3189                      5                       9                       6
# 3276                      5                      10                       9
# 3297                      7                      10                       9
# 3352                     10                       7                       8
# 3385                      5                      11                      13
# 3478                     15                      12                       8
# 3698                      4                      16                      11
# 3755                      6                      10                       3
# 3764                      3                      12                      16
# 3770                     11                       8                       8
# 3791                      7                      15                      11
#
#       HomeTeamCorners  AwayTeamCorners  HomeTeamYellowCards  \
# 40                  5                5                    1
# 179                10                6                    0
# 305                 2                4                    2
# 348                 0                5                    2
# 625                 6                4                    1
# 685                 4                4                    0
# 787                 3                2                    6
# 869                 2                0                    0
# 949                 0                3                    3
# 989                 2                4                    3
# 1133                2                3                    0
# 1142                8                5                    3
# 1186                3               11                    2
# 1202                4                7                    1
# 1257                3                4                    2
# 1272                5                5                    2
# 1306                9                9                    1
# 1317                2                3                    1
# 1419                6                1                    1
# 1446                2               11                    0
# 1572                1                9                    1
# 1596               10                7                    3
# 1646                8                1                    0
# 1721                5                3                    1
# 1945                7                5                    1
# 2068                3                3                    1
# 2342               11                1                    1
# 2407                5                4                    1
# 2442                5                3                    3
# 2583                0                8                    1
# 2604                8                5                    1
# 2746                7                6                    2
# 2825                1                4                    3
# 2845                9                1                    0
# 2909                3                6                    4
# 3010                9                5                    1
# 3110                1                8                    2
# 3189                5                5                    0
# 3276                4                6                    2
# 3297                4                8                    0
# 3352                8                5                    1
# 3385               15                1                    1
# 3478                2                6                    3
# 3698               11                3                    1
# 3755                4                4                    2
# 3764                8                6                    2
# 3770                4               11                    2
# 3791                3                0                    4
#
#       AwayTeamYellowCards  HomeTeamRedCards  AwayTeamRedCards
# 40                      3                 0                 0
# 179                     1                 0                 0
# 305                     3                 1                 0
# 348                     0                 0                 0
# 625                     0                 0                 0
# 685                     1                 0                 0
# 787                     1                 0                 0
# 869                     2                 0                 0
# 949                     0                 0                 0
# 989                     3                 0                 0
# 1133                    0                 0                 0
# 1142                    3                 2                 0
# 1186                    0                 0                 0
# 1202                    1                 0                 0
# 1257                    3                 0                 0
# 1272                    1                 0                 0
# 1306                    0                 0                 0
# 1317                    1                 0                 0
# 1419                    1                 0                 0
# 1446                    0                 0                 0
# 1572                    1                 0                 0
# 1596                    1                 1                 0
# 1646                    0                 0                 0
# 1721                    0                 0                 0
# 1945                    2                 0                 0
# 2068                    4                 0                 0
# 2342                    2                 0                 0
# 2407                    0                 0                 0
# 2442                    1                 0                 0
# 2583                    0                 0                 0
# 2604                    2                 0                 0
# 2746                    3                 0                 0
# 2825                    1                 0                 0
# 2845                    2                 0                 0
# 2909                    2                 0                 0
# 3010                    1                 0                 0
# 3110                    0                 1                 0
# 3189                    0                 0                 0
# 3276                    2                 0                 0
# 3297                    1                 0                 0
# 3352                    2                 0                 0
# 3385                    5                 0                 0
# 3478                    0                 0                 0
# 3698                    2                 0                 0
# 3755                    0                 0                 0
# 3764                    1                 0                 0
# 3770                    2                 0                 0
# 3791                    4                 0                 0
#
# [48 rows x 23 columns]

# %% [markdown]
# Number of times a Home team has been winning 3-0 at half time

# %%
HomeWinning3.shape[0]
# Out:
# 75

# %% [markdown]
# Number of times an Away team has been winning 3-0 at half time

# %%
AwayWinning3.shape[0]
# Out:
# 48

# %% [markdown]
# Plotting the results into a pie chart

# %%
HomeWinning3 = HomeWinning3.copy()
HomeWinning3["FullTimeOutcome"] = HomeWinning3.apply(
    lambda row: "Win" if row["FullTimeHomeTeamGoals"] > row["FullTimeAwayTeamGoals"] 
                else "Draw" if row["FullTimeHomeTeamGoals"] == row["FullTimeAwayTeamGoals"] 
                else "Loss", axis=1
)

OutcomeHome3 = HomeWinning3["FullTimeOutcome"].value_counts()
OutcomeHome3.plot(
    kind='pie', 
    autopct='%1.1f%%',
    figsize=(8, 8), 
    colors=['#66b3ff', '#99ff99', '#ff9999']) 
plt.ylabel('Outcome');
plt.title("Full-Time Outcome When Home Team Leads 3-0 at Half-Time");

# %%
AwayWinning3 = AwayWinning3.copy()
AwayWinning3["FullTimeOutcome"] = AwayWinning3.apply(
    lambda row: "Win" if row["FullTimeAwayTeamGoals"] > row["FullTimeHomeTeamGoals"] 
                else "Draw" if row["FullTimeAwayTeamGoals"] == row["FullTimeHomeTeamGoals"] 
                else "Loss", axis=1
)

OutcomeAway3 = AwayWinning3["FullTimeOutcome"].value_counts()
OutcomeAway3.plot(
    kind='pie', 
    autopct='%1.2f%%',
    figsize=(8, 8), 
    colors=['#66b3ff', '#99ff99', '#ff9999']) 
plt.ylabel('Outcome');
plt.title("Full-Time Outcome When Away Team Leads 3-0 at Half-Time");

# %% [markdown]
# Now that we have all of our pie charts, let's undertake a compartive analysis of the three different scorelines

# %% [markdown]
# Below we are transforming the outcomes into percentages to make it easier for to undertake a compartive analysis within a bar chart

# %%
OutcomeHome1Percent = (HomeWinning1["FullTimeOutcome"].value_counts(normalize=True) * 100).round(2)
OutcomeHome2Percent = (HomeWinning2["FullTimeOutcome"].value_counts(normalize=True) * 100).round(2)
OutcomeHome3Percent = (HomeWinning3["FullTimeOutcome"].value_counts(normalize=True) * 100).round(2)
OutcomeAway1Percent = (AwayWinning1["FullTimeOutcome"].value_counts(normalize=True) * 100).round(2)
OutcomeAway2Percent = (AwayWinning2["FullTimeOutcome"].value_counts(normalize=True) * 100).round(2)
OutcomeAway3Percent = (AwayWinning3["FullTimeOutcome"].value_counts(normalize=True) * 100).round(2)

# %% [markdown]
# Here we combine all of the home outcomes into one data frame

# %%
# Let's start by combining all of the home outcomes into one data frame

HomeCombined_df = pd.DataFrame({
    "FT Outcome When Home Team is Winning 1-0 at HT" : OutcomeHome1Percent,
    "FT Outcome When Home Team is Winning 2-0 at HT" : OutcomeHome2Percent,
    "FT Outcome When Home Team is Winning 3-0 at HT" : OutcomeHome3Percent

})

HomeCombined_df
# Out:
#                  FT Outcome When Home Team is Winning 1-0 at HT  \
# FullTimeOutcome
# Draw                                                      18.76
# Loss                                                       8.37
# Win                                                       72.87
#
#                  FT Outcome When Home Team is Winning 2-0 at HT  \
# FullTimeOutcome
# Draw                                                       4.86
# Loss                                                       1.74
# Win                                                       93.40
#
#                  FT Outcome When Home Team is Winning 3-0 at HT
# FullTimeOutcome
# Draw                                                       2.67
# Loss                                                        NaN
# Win                                                       97.33

# %% [markdown]
# Let's transform the table into a bar chart for easier analysis

# %%
HomeCombinedPlot=HomeCombined_df.plot(
    kind='bar', 
    figsize=(8, 8), 
    )

    
HomeCombinedPlot.set_title('Full Time Outcome of Home Teams')
HomeCombinedPlot.set_xlabel('Outcome at Full Time') 
HomeCombinedPlot.set_ylabel('%') 
HomeCombinedPlot.bar_label(HomeCombinedPlot.containers[0])

for HomeContainer in HomeCombinedPlot.containers:
    HomeCombinedPlot.bar_label(HomeContainer)

# %% [markdown]
# When the Home team is winning 1-0 at half time, they win 72.87% of the games, as the half time scoreline increases, they win more and more games as evidenced by the data which states when winning 2-0 and 3-0, the Home team wins 93.4% and 97.33% of the games.<br /><br />
# This concurs with common sense as the the bigger the goal difference between the Home and Away sides, the harder it is for the losing team to win the game.<br />
#  As a result of the aforementioned effect the larger half time lead will lead to fewer draws and losses.<br />
#
# To summarise, the data supports the idea that larger half time scores create larger scoreline security for the winning team.

# %% [markdown]
# Let's now extend the above analyis to Away teams

# %%
AwayCombined_df = pd.DataFrame({
    "FT Outcome When Away Team is Winning 1-0 at HT" : OutcomeAway1Percent,
    "FT Outcome When Away Team is Winning 2-0 at HT" : OutcomeAway2Percent,
    "FT Outcome When Away Team is Winning 3-0 at HT" : OutcomeAway3Percent

})

# %%
AwayCombined_df
# Out:
#                  FT Outcome When Away Team is Winning 1-0 at HT  \
# FullTimeOutcome
# Draw                                                      22.16
# Loss                                                      13.26
# Win                                                       64.57
#
#                  FT Outcome When Away Team is Winning 2-0 at HT  \
# FullTimeOutcome
# Draw                                                       6.19
# Loss                                                       4.64
# Win                                                       89.18
#
#                  FT Outcome When Away Team is Winning 3-0 at HT
# FullTimeOutcome
# Draw                                                        NaN
# Loss                                                       2.08
# Win                                                       97.92

# %%
AwayCombinedPlot = AwayCombined_df.plot(
    kind='bar', 
    figsize=(8, 8), 
    )
    
    
    
AwayCombinedPlot.set_title('Full Time Outcome of Away Teams')
AwayCombinedPlot.set_xlabel('Outcome at Full Time') 
AwayCombinedPlot.set_ylabel('%') 
AwayCombinedPlot.bar_label(AwayCombinedPlot.containers[0])

for AwayContainer in AwayCombinedPlot.containers:
    AwayCombinedPlot.bar_label(AwayContainer)

# %% [markdown]
# The data shows that when the Away team is winning 1-0 at half time, they win 64.57% of the games, when the half time scoreline increases to 2-0, they win 89.18% of the games and finally, when they are winning 3-0 their win percentage increasaes to 97.12%. <br /><br />
# The same effect discussed within the Home team analysis can be seen here aswell, the larger the half time scoreline, the larger the win percentage<br/>
# The phenomenon spoke about earlier in the project can be evidenced here just by comparing this bar chart with the Home bar chart - it is clear to see when teams are at Home, they generally perform better than if they were Away as evidenced by the higher win % when at Home.<br />
# <br />

# %% [markdown]
# In order to take our Home vs Away analysis further, we will now be using Power BI to create a dashboard of certain metrics to visualise the difference between playing at Home vs Away. <br />
# Below we are going export our cleaned data into xlsx which will then be imported into Power BI.

# %%
df.to_excel('CombinedPremierLeagueData14to24.xlsx', index=False)
